# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# read the dataset and display table information
df_24 = pd.read_csv('../../data/raw/survey_2024.csv')

# %%
display(df_24.head(2), df_24.info(), df_24.nunique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65437 entries, 0 to 65436
# Columns: 114 entries, ResponseId to JobSat
# dtypes: float64(13), int64(1), object(100)
# memory usage: 56.9+ MB
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
#
#                                         EdLevel  \
# 0                     Primary/elementary school
# 1  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0                             Books / Physical media
# 1  Books / Physical media;Colleague;On the job tr...
#
#                                      LearnCodeOnline  ... JobSatPoints_6  \
# 0                                                NaN  ...            NaN
# 1  Technical documentation;Blogs;Books;Written Tu...  ...            0.0
#
#   JobSatPoints_7 JobSatPoints_8 JobSatPoints_9 JobSatPoints_10  \
# 0            NaN            NaN            NaN             NaN
# 1            0.0            0.0            0.0             0.0
#
#   JobSatPoints_11 SurveyLength SurveyEase ConvertedCompYearly JobSat
# 0             NaN          NaN        NaN                 NaN    NaN
# 1             0.0          NaN        NaN                 NaN    NaN
#
# [2 rows x 114 columns]
# None
# ResponseId             65437
# MainBranch                 5
# Age                        8
# Employment               110
# RemoteWork                 3
#                        ...
# JobSatPoints_11           79
# SurveyLength               3
# SurveyEase                 3
# ConvertedCompYearly     6113
# JobSat                    11
# Length: 114, dtype: int64

# %%
# Select only the interesting columns
df_24 = df_24[["Country", "Age", "Employment", "RemoteWork", "EdLevel", "YearsCode", "YearsCodePro", "DevType", "Currency", "CompTotal"]]
df_24.head()
# Out:
#                                              Country                 Age  \
# 0                           United States of America  Under 18 years old
# 1  United Kingdom of Great Britain and Northern I...     35-44 years old
# 2  United Kingdom of Great Britain and Northern I...     45-54 years old
# 3                                             Canada     18-24 years old
# 4                                             Norway     18-24 years old
#
#             Employment RemoteWork  \
# 0  Employed, full-time     Remote
# 1  Employed, full-time     Remote
# 2  Employed, full-time     Remote
# 3   Student, full-time        NaN
# 4   Student, full-time        NaN
#
#                                              EdLevel YearsCode YearsCodePro  \
# 0                          Primary/elementary school       NaN          NaN
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)        20           17
# 2    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)        37           27
# 3  Some college/university study without earning ...         4          NaN
# 4  Secondary school (e.g. American high school, G...         9          NaN
#
#                  DevType Currency  CompTotal
# 0                    NaN      NaN        NaN
# 1  Developer, full-stack      NaN        NaN
# 2   Developer Experience      NaN        NaN
# 3  Developer, full-stack      NaN        NaN
# 4  Developer, full-stack      NaN        NaN

# %%
# Rename columns
df_24 = df_24.rename({"Country": "country", "Age": "age_range", "Employment": "employment", "RemoteWork": "remote_work", "EdLevel": "education_level", "YearsCode": "years_coding", "YearsCodePro": "years_coding_pro", "DevType": "type", "Currency": "currency", "CompTotal": "salary"}, axis=1)
display(df_24)
# Out:
#                                                  country           age_range  \
# 0                               United States of America  Under 18 years old
# 1      United Kingdom of Great Britain and Northern I...     35-44 years old
# 2      United Kingdom of Great Britain and Northern I...     45-54 years old
# 3                                                 Canada     18-24 years old
# 4                                                 Norway     18-24 years old
# ...                                                  ...                 ...
# 65432                                                NaN     18-24 years old
# 65433                                                NaN     25-34 years old
# 65434                                                NaN     25-34 years old
# 65435                                            Germany     18-24 years old
# 65436                                                NaN     18-24 years old
#
#                 employment                           remote_work  \
# 0      Employed, full-time                                Remote
# 1      Employed, full-time                                Remote
# 2      Employed, full-time                                Remote
# 3       Student, full-time                                   NaN
# 4       Student, full-time                                   NaN
# ...                    ...                                   ...
# 65432  Employed, full-time                                Remote
# 65433  Employed, full-time                                Remote
# 65434  Employed, full-time                             In-person
# 65435  Employed, full-time  Hybrid (some remote, some in-person)
# 65436   Student, full-time                                   NaN
#
#                                          education_level years_coding  \
# 0                              Primary/elementary school          NaN
# 1           Bachelor’s degree (B.A., B.S., B.Eng., etc.)           20
# 2        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)           37
# 3      Some college/university study without earning ...            4
# 4      Secondary school (e.g. American high school, G...            9
# ...                                                  ...          ...
# 65432       Bachelor’s degree (B.A., B.S., B.Eng., etc.)            5
# 65433                                                NaN          NaN
# 65434       Bachelor’s degree (B.A., B.S., B.Eng., etc.)            9
# 65435  Secondary school (e.g. American high school, G...            5
# 65436                                                NaN          NaN
#
#       years_coding_pro                   type           currency  salary
# 0                  NaN                    NaN                NaN     NaN
# 1                   17  Developer, full-stack                NaN     NaN
# 2                   27   Developer Experience                NaN     NaN
# 3                  NaN  Developer, full-stack                NaN     NaN
# 4                  NaN  Developer, full-stack                NaN     NaN
# ...                ...                    ...                ...     ...
# 65432                3             Blockchain                NaN     NaN
# 65433              NaN                    NaN                NaN     NaN
# 65434                5      Developer, mobile                NaN     NaN
# 65435                2    Developer, back-end  EUR European Euro     NaN
# 65436              NaN                    NaN                NaN     NaN
#
# [65437 rows x 10 columns]

# %%
df_24 = df_24[df_24["salary"].notnull()]
display(df_24, df_24.info(), df_24.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33740 entries, 72 to 65431
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   country           33740 non-null  object
#  1   age_range         33740 non-null  object
#  2   employment        33740 non-null  object
#  3   remote_work       33727 non-null  object
#  4   education_level   33740 non-null  object
#  5   years_coding      33681 non-null  object
#  6   years_coding_pro  33617 non-null  object
#  7   type              33703 non-null  object
#  8   currency          33740 non-null  object
#  9   salary            33740 non-null  float64
# dtypes: float64(1), object(9)
# memory usage: 2.8+ MB
#                         country        age_range  \
# 72                     Pakistan  18-24 years old
# 374                     Austria  25-34 years old
# 379                      Turkey  35-44 years old
# 385                      France  35-44 years old
# 389    United States of America  25-34 years old
# ...                         ...              ...
# 65396                 Lithuania  18-24 years old
# 65401                    France  25-34 years old
# 65408                    France  25-34 years old
# 65412                     Italy  35-44 years old
# 65431                   Belgium  45-54 years old
#
#                                               employment  \
# 72     Employed, full-time;Student, full-time;Indepen...
# 374                                  Employed, full-time
# 379                                  Employed, full-time
# 385    Independent contractor, freelancer, or self-em...
# 389               Employed, full-time;Student, part-time
# ...                                                  ...
# 65396  Employed, full-time;Independent contractor, fr...
# 65401                                Employed, full-time
# 65408                                Employed, full-time
# 65412                                Employed, full-time
# 65431                                Employed, full-time
#
#                                 remote_work  \
# 72     Hybrid (some remote, some in-person)
# 374    Hybrid (some remote, some in-person)
# 379                                  Remote
# 385                                  Remote
# 389                                  Remote
# ...                                     ...
# 65396  Hybrid (some remote, some in-person)
# 65401  Hybrid (some remote, some in-person)
# 65408  Hybrid (some remote, some in-person)
# 65412                                Remote
# 65431  Hybrid (some remote, some in-person)
#
#                                          education_level years_coding  \
# 72     Secondary school (e.g. American high school, G...            3
# 374       Professional degree (JD, MD, Ph.D, Ed.D, etc.)           12
# 379      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)           15
# 385      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)           27
# 389    Some college/university study without earning ...            7
# ...                                                  ...          ...
# 65396  Secondary school (e.g. American high school, G...            3
# 65401       Bachelor’s degree (B.A., B.S., B.Eng., etc.)           10
# 65408    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)           13
# 65412       Bachelor’s degree (B.A., B.S., B.Eng., etc.)           20
# 65431       Bachelor’s degree (B.A., B.S., B.Eng., etc.)           38
#
#       years_coding_pro                                           type  \
# 72                   1  Data scientist or machine learning specialist
# 374                  6                            Academic researcher
# 379                  6  Data scientist or machine learning specialist
# 385                 17                            Developer, back-end
# 389                  7                                        Student
# ...                ...                                            ...
# 65396                3                          Developer, full-stack
# 65401                7                          Developer, full-stack
# 65408                9                          Developer, full-stack
# 65412               18                            Developer, back-end
# 65431               24                          Developer, full-stack
#
#                         currency     salary
# 72          PKR\tPakistani rupee  2040000.0
# 374            EUR European Euro    28000.0
# 379            EUR European Euro    85000.0
# 385            EUR European Euro    50000.0
# 389    USD\tUnited States dollar   110000.0
# ...                          ...        ...
# 65396          EUR European Euro    36000.0
# 65401          EUR European Euro    40000.0
# 65408          EUR European Euro    61000.0
# 65412          EUR European Euro    58000.0
# 65431          EUR European Euro    55000.0
#
# [33740 rows x 10 columns]
# None
# country               0
# age_range             0
# employment            0
# remote_work          13
# education_level       0
# years_coding         59
# years_coding_pro    123
# type                 37
# currency              0
# salary                0
# dtype: int64

# %%
display(df_24["country"].value_counts(), df_24["country"].nunique())
#display(df_24["age"].value_counts())
#display(df_24["employment"].value_counts())
#display(df_24["remote_work"].value_counts())
#display(df_24["education_level"].value_counts())
#display(df_24["years_coding"].value_counts())
#display(df_24["years_coding_pro"].value_counts())
#display(df_24["type"].value_counts())
#display(df_24["currency"].value_counts())
#display(df_24["salary"].value_counts())
# Out:
# country
# United States of America                                7042
# Germany                                                 3004
# United Kingdom of Great Britain and Northern Ireland    2008
# Ukraine                                                 1610
# India                                                   1551
#                                                         ...
# Gabon                                                      1
# Antigua and Barbuda                                        1
# Democratic Republic of the Congo                           1
# Niger                                                      1
# Monaco                                                     1
# Name: count, Length: 170, dtype: int64
# 170

# %%
# Define function toreduce category count
def shorten_categories(categories, cutoff):
    categorical_map = {}
    for category, count in categories.items():
        if count >= cutoff:
            categorical_map[category] = category
        else:
            categorical_map[category] = "Other"
    return categorical_map

# %%
# Create the mapping with a cutoff of 400 counts
country_map = shorten_categories(country_value_counts, 400)
df_24["country"] = df_24["country"].map(country_map)

# Check the value counts after mapping
print("\nCountry Value Counts After Mapping:")
print(df_24["country"].value_counts())
# Out:
# Country Value Counts After Mapping:
# country
# United States of America                                7042
# Germany                                                 3004
# United Kingdom of Great Britain and Northern Ireland    2008
# Ukraine                                                 1610
# India                                                   1551
# France                                                  1331
# Canada                                                  1282
# Brazil                                                   933
# Poland                                                   890
# Netherlands                                              873
# Spain                                                    789
# Italy                                                    775
# Australia                                                750
# Sweden                                                   689
# Switzerland                                              560
# Austria                                                  495
# Czech Republic                                           408
# Name: count, dtype: int64

# %%
display(df_24, df_24['country'].unique())
# Out:
#                         country        age_range  \
# 72                          NaN  18-24 years old
# 374                     Austria  25-34 years old
# 379                         NaN  35-44 years old
# 385                      France  35-44 years old
# 389    United States of America  25-34 years old
# ...                         ...              ...
# 65396                       NaN  18-24 years old
# 65401                    France  25-34 years old
# 65408                    France  25-34 years old
# 65412                     Italy  35-44 years old
# 65431                       NaN  45-54 years old
#
#                                               employment  \
# 72     Employed, full-time;Student, full-time;Indepen...
# 374                                  Employed, full-time
# 379                                  Employed, full-time
# 385    Independent contractor, freelancer, or self-em...
# 389               Employed, full-time;Student, part-time
# ...                                                  ...
# 65396  Employed, full-time;Independent contractor, fr...
# 65401                                Employed, full-time
# 65408                                Employed, full-time
# 65412                                Employed, full-time
# 65431                                Employed, full-time
#
#                                 remote_work  \
# 72     Hybrid (some remote, some in-person)
# 374    Hybrid (some remote, some in-person)
# 379                                  Remote
# 385                                  Remote
# 389                                  Remote
# ...                                     ...
# 65396  Hybrid (some remote, some in-person)
# 65401  Hybrid (some remote, some in-person)
# 65408  Hybrid (some remote, some in-person)
# 65412                                Remote
# 65431  Hybrid (some remote, some in-person)
#
#                                          education_level years_coding  \
# 72     Secondary school (e.g. American high school, G...            3
# 374       Professional degree (JD, MD, Ph.D, Ed.D, etc.)           12
# 379      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)           15
# 385      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)           27
# 389    Some college/university study without earning ...            7
# ...                                                  ...          ...
# 65396  Secondary school (e.g. American high school, G...            3
# 65401       Bachelor’s degree (B.A., B.S., B.Eng., etc.)           10
# 65408    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)           13
# 65412       Bachelor’s degree (B.A., B.S., B.Eng., etc.)           20
# 65431       Bachelor’s degree (B.A., B.S., B.Eng., etc.)           38
#
#       years_coding_pro                                           type  \
# 72                   1  Data scientist or machine learning specialist
# 374                  6                            Academic researcher
# 379                  6  Data scientist or machine learning specialist
# 385                 17                            Developer, back-end
# 389                  7                                        Student
# ...                ...                                            ...
# 65396                3                          Developer, full-stack
# 65401                7                          Developer, full-stack
# 65408                9                          Developer, full-stack
# 65412               18                            Developer, back-end
# 65431               24                          Developer, full-stack
#
#                         currency     salary
# 72          PKR\tPakistani rupee  2040000.0
# 374            EUR European Euro    28000.0
# 379            EUR European Euro    85000.0
# 385            EUR European Euro    50000.0
# 389    USD\tUnited States dollar   110000.0
# ...                          ...        ...
# 65396          EUR European Euro    36000.0
# 65401          EUR European Euro    40000.0
# 65408          EUR European Euro    61000.0
# 65412          EUR European Euro    58000.0
# 65431          EUR European Euro    55000.0
#
# [33740 rows x 10 columns]
# array([nan, 'Austria', 'France', 'United States of America',
#        'United Kingdom of Great Britain and Northern Ireland', 'Brazil',
#        'Germany', 'Italy', 'Ukraine', 'Czech Republic', 'Canada',
#        'Switzerland', 'India', 'Spain', 'Sweden', 'Netherlands', 'Poland',
#        'Australia'], dtype=object)
